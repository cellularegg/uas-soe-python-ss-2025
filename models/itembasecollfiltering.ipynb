# %% [markdown]
# # Item-based Collaborative Filtering
#
# Core idea
# “If two movies get similar rating patterns from many users, then someone who liked one of those movies will probably like the other as well.”
#
# How it works
#   1. For every movie the target user has rated, find similar movies (e.g., by cosine similarity of rating vectors).
#   2. Score those similar movies—weight by how much the user liked the original movie and by the similarity strength.
#   3. Rank the unseen movies by the aggregated scores.
#   4. Recommend the top-ranked ones to the user.
#
# Example
# Many users who liked Inception also liked Interstellar and The Matrix.
# Alice rated Inception and The Matrix highly but hasn’t watched Interstellar.
# Because both of Alice’s liked movies point to Interstellar as a close neighbour, the system recommends Interstellar to Alice.

# %%
# Load datasets
import pandas as pd
movies = pd.read_csv("../data/csv/movies.csv")
ratings = pd.read_csv("../data/csv/ratings.csv")

# %%
# Merge ratings with movie titles
movies_ratings = ratings.merge(movies[['movieId', 'title']], on='movieId', how='left')

print(movies_ratings.shape)
movies_ratings.head()
# Out:
# (25000095, 5)
#    userId  movieId  rating   timestamp  \
# 0       1      296     5.0  1147880044
# 1       1      306     3.5  1147868817
# 2       1      307     5.0  1147868828
# 3       1      665     5.0  1147878820
# 4       1      899     3.5  1147868510
#
#                                               title
# 0                               Pulp Fiction (1994)
# 1  Three Colors: Red (Trois couleurs: Rouge) (1994)
# 2  Three Colors: Blue (Trois couleurs: Bleu) (1993)
# 3                                Underground (1995)
# 4                        Singin' in the Rain (1952)

# %% [markdown]
# ## Option 1: Filter to “Active” Users and/or “Popular” Movies
#
# We do this, because the full dataset is too computationally expensive for personal laptops.

# %%
# Keep users with at least 500 ratings
user_counts = movies_ratings['userId'].value_counts()
active_users = user_counts[user_counts >= 100].index

# Keep movies with at least 1000 ratings
movie_counts = movies_ratings['movieId'].value_counts()
popular_movies = movie_counts[movie_counts >= 500].index

# Filter the DataFrame
movies_ratings_filtered = movies_ratings[
    movies_ratings['userId'].isin(active_users) &
    movies_ratings['movieId'].isin(popular_movies)
]

print(movies_ratings_filtered.shape)
movies_ratings_filtered.head()
# Out:
# (18772328, 5)
#     userId  movieId  rating   timestamp                      title
# 70       2        1     3.5  1141415820           Toy Story (1995)
# 71       2       62     0.5  1141417130  Mr. Holland's Opus (1995)
# 72       2      110     5.0  1141416589          Braveheart (1995)
# 73       2      150     4.0  1141415790           Apollo 13 (1995)
# 74       2      151     4.5  1141415643             Rob Roy (1995)

# %% [markdown]
# ### Lenskit implementation

# %%
from lenskit.data import from_interactions_df
from lenskit.knn import ItemKNNScorer
from lenskit.splitting import sample_records
from lenskit import pipeline, recommend

# convert df to a Dataset (new in LensKit 2025.2.0)
lk_dataset = from_interactions_df(movies_ratings_filtered, 
                                   user_col='userId', 
                                   item_col='movieId', 
                                   rating_col='rating', 
                                   timestamp_col='timestamp')
lk_dataset
pd_lk_dataset = lk_dataset.interaction_matrix(format='pandas')
pd_lk_dataset
# Out:
#           user_num  item_num  rating   timestamp  \
# 0                0         0     3.5  1141415820
# 1                0        54     0.5  1141417130
# 2                0        92     5.0  1141416589
# 3                0       113     4.0  1141415790
# 4                0       114     4.5  1141415643
# ...            ...       ...     ...         ...
# 18772323     63891      4027     4.5  1240953372
# 18772324     63891      4139     2.5  1240951998
# 18772325     63891      4153     2.0  1240950697
# 18772326     63891      4198     4.0  1240953434
# 18772327     63891      4289     5.0  1240952515
#
#                                    title
# 0                       Toy Story (1995)
# 1              Mr. Holland's Opus (1995)
# 2                      Braveheart (1995)
# 3                       Apollo 13 (1995)
# 4                         Rob Roy (1995)
# ...                                  ...
# 18772323              Ratatouille (2007)
# 18772324                Bee Movie (2007)
# 18772325  Alvin and the Chipmunks (2007)
# 18772326         Dark Knight, The (2008)
# 18772327                     Milk (2008)
#
# [18772328 rows x 5 columns]

# %%
# we also can get some statistics from the Dataset object 
lk_dataset.item_stats()
# lk_dataset.user_stats()
# Out:
# /home/toporek3112/miniconda3/envs/ml-3.13/lib/python3.13/site-packages/lenskit/data/relationships.py:588: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'NaT' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   stats.loc[stats["count"] == 0, "first_time"] = pd.NaT
# /home/toporek3112/miniconda3/envs/ml-3.13/lib/python3.13/site-packages/lenskit/data/relationships.py:590: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'NaT' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   stats.loc[stats["count"] == 0, "last_time"] = pd.NaT
#          record_count  user_count  rating_count  mean_rating  count  \
# item_id
# 1               36139       36139         36139     3.867235  36139
# 2               18422       18422         18422     3.168983  18422
# 3                6572        6572          6572     3.027998   6572
# 4                1925        1925          1925     2.774286   1925
# 5                6355        6355          6355     2.935169   6355
# ...               ...         ...           ...          ...    ...
# 197711            689         689           689     3.537736    689
# 200818            662         662           662     3.619335    662
# 201773            930         930           930     3.680108    930
# 202429            731         731           731     3.876881    731
# 204698            667         667           667     4.035232    667
#
#          first_time   last_time
# item_id
# 1         826437752  1574285022
# 2         822873600  1574276821
# 3         825582938  1573439445
# 4         825582938  1574213055
# 5         826962728  1573033018
# ...             ...         ...
# 197711   1552750151  1574294960
# 200818   1554956153  1574290269
# 201773   1558380688  1574280869
# 202429   1563592457  1574219415
# 204698   1570053344  1574312995
#
# [5386 rows x 7 columns]

# %%
# split into test and train sets
from lenskit.splitting import sample_records
test_size = round(lk_dataset.interaction_count * 0.2)
split = sample_records(lk_dataset, test_size) # creates test split with 3000 records and train split with the rest

# %%
# train
pipe = pipeline.topn_pipeline(ItemKNNScorer(), n=20)
pipe.train(split.train)
# Out:
# /home/toporek3112/miniconda3/envs/ml-3.13/lib/python3.13/site-packages/lenskit/data/relationships.py:378: UserWarning: Sparse CSR tensor support is in beta state. If you miss a functionality in the sparse tensor support, please submit a feature request to https://github.com/pytorch/pytorch/issues. (Triggered internally at /opt/conda/conda-bld/libtorch_1745854776362/work/aten/src/ATen/SparseCsrTensorImpl.cpp:53.)
#   return torch.sparse_csr_tensor(

# %%
# bratch recommend to users in test set
from lenskit.batch import recommend as batch_recommend

recs = batch_recommend(pipe, list(split.test.keys()), n=10)

# %%
# convert to dataframes
df_recs = recs.to_df()
df_test = split.test_df

# %%
# validate recommendations
from sklearn.metrics import mean_squared_error

# keep only the columns we need and join on user & item
merged = (
  df_test[['user_id', 'item_id', 'rating']]
    .merge(df_recs[['user_id', 'item_id', 'score']],
           on=['user_id', 'item_id'],
           how='inner')          # drop pairs without predictions
)

mse  = mean_squared_error(merged['rating'], merged['score'])
rmse = mse ** 0.5 

print('MSE:', mse)
print('RMSE:', rmse)
# Out:
# MSE: 0.32750095382607425
# RMSE: 0.5722769904740835

# %%
# test recommendations for a specific user
user_id = lk_dataset.users.index[3]
recs = recommend(pipe, user_id, n=15)
recs_df = recs.to_df()

print("Recommendations for user", user_id)
movies_ratings[movies_ratings['movieId'].isin(recs.ids())]
# Out:
# Recommendations for user 5
#           userId  movieId  rating   timestamp  \
# 79             2      318     5.0  1141417181
# 153            2     2324     1.5  1141417726
# 257            3       50     5.0  1439474391
# 265            3      318     4.0  1439472424
# 315            3     2329     5.0  1439474463
# ...          ...      ...     ...         ...
# 24999882  162540    49530     5.0  1248855507
# 24999916  162541       50     5.0  1240953428
# 24999927  162541      318     4.0  1240952695
# 25000002  162541     2324     4.5  1240953595
# 25000003  162541     2329     4.5  1240950831
#
#                                                title
# 79                  Shawshank Redemption, The (1994)
# 153       Life Is Beautiful (La Vita è bella) (1997)
# 257                       Usual Suspects, The (1995)
# 265                 Shawshank Redemption, The (1994)
# 315                        American History X (1998)
# ...                                              ...
# 24999882                        Blood Diamond (2006)
# 24999916                  Usual Suspects, The (1995)
# 24999927            Shawshank Redemption, The (1994)
# 25000002  Life Is Beautiful (La Vita è bella) (1997)
# 25000003                   American History X (1998)
#
# [256498 rows x 5 columns]

# %%
# movies the user already watched
movies_ratings[movies_ratings['userId'] == user_id].sort_values('rating', ascending=False).head(10)
# Out:
#       userId  movieId  rating  timestamp  \
# 1154       5       32     5.0  830786277
# 1155       5       36     5.0  830786409
# 1164       5      141     5.0  858625837
# 1158       5       50     5.0  831900118
# 1157       5       47     5.0  833146729
# 1166       5      150     5.0  830786155
# 1188       5      337     5.0  830786345
# 1183       5      292     5.0  830786263
# 1165       5      147     5.0  830786700
# 1179       5      260     5.0  858625863
#
#                                           title
# 1154  Twelve Monkeys (a.k.a. 12 Monkeys) (1995)
# 1155                    Dead Man Walking (1995)
# 1164                       Birdcage, The (1996)
# 1158                 Usual Suspects, The (1995)
# 1157                Seven (a.k.a. Se7en) (1995)
# 1166                           Apollo 13 (1995)
# 1188         What's Eating Gilbert Grape (1993)
# 1183                            Outbreak (1995)
# 1165             Basketball Diaries, The (1995)
# 1179  Star Wars: Episode IV - A New Hope (1977)

# %%
# perform a cross-validation 
from lenskit.data import ItemListCollection, UserIDKey
from lenskit.splitting import crossfold_records, SampleFrac
from lenskit.metrics import Precision, Recall, NDCG, RunAnalysis
from lenskit.metrics import RunAnalysis, RBP, TestItemCount, ListLength, MAE, RMSE, Precision, Recall, Hit
from lenskit.basic import UserTrainingHistoryLookup


base = pipeline.topn_pipeline(ItemKNNScorer(), n=23) 

# Set up containers to collect test interactions and recommendations for all folds
all_test = ItemListCollection(UserIDKey)           # test interactions by user
all_recs = ItemListCollection(UserIDKey)           # recommended item lists by user

folds = 5
# Perform 5-fold cross-validation
for fold, split in enumerate(crossfold_records(lk_dataset, rng=9, partitions=folds)):
    print(f"Processing fold {fold}...")
    all_test.add_from(split.test)  

    # Clone and train the pipeline on the training portion of this fold
    algo = base.clone() 
    algo.train(split.train)

    # Generate top-10 recommendations for each user in the test set of this fold
    recs = batch_recommend(algo, list(split.test.keys()), n=10) 
    all_recs.add_from(recs)
# Out:
# Processing fold 0...
# Processing fold 1...
# Processing fold 2...
# Processing fold 3...
# Processing fold 4...

# %%
# Set up the evaluation with desired metrics
analysis = RunAnalysis()
analysis.add_metric(Precision())
analysis.add_metric(Recall())
analysis.add_metric(NDCG())
analysis.add_metric(Hit())

# Measure the recommendations against the test data
results = analysis.measure(all_recs, all_test)

metrics_df = results.list_metrics()
avg_metrics = metrics_df.mean()

print(f"metrics over {folds}-fold CV over {len(lk_dataset)} samples:")
print(avg_metrics)
# Out:
# metrics over 5-fold CV:
# Precision    0.000419
# Recall       0.000005
# NDCG         0.000019
# Hit          0.000419
# dtype: float64

# %%
rec_df = all_recs.to_df()
test_df = all_test.to_df()
# Out:
# /tmp/ipykernel_177198/2918802180.py:1: DataWarning: item list collection has empty lists, they will be dropped
#   rec_df = all_recs.to_df()

# %%
# test_df.shape
# rec_df.shape
# test_df[(test_df['user_id'] == 3) & (test_df['item_id'] == 77561)]
# Out:
# (3754465, 5)

# %%
# recommend
# user_id = 
# recs = recommend(pipe, user_id, n=15)
# recs_df = recs.to_df()

# print("Recommendations for user", user_id)
# movies_ratings[movies_ratings['movieId'].isin(recs.ids())]

recs = recommend(base, lk_dataset.users.index[5], n=10) 
recs.to_df().head()
# Out:
# ╭─────────────────────────────── Traceback (most recent call last) ────────────────────────────────╮
# │ /home/toporek3112/miniconda3/envs/ml-3.13/lib/python3.13/site-packages/lenskit/pipeline/runner.p │
# │ y:70 in run                                                                                      │
# │                                                                                                  │
# │    67 │   │   trace(log, "processing node")                                                      │
# │    68 │   │   self.status[node.name] = "in-progress"                                             │
# │    69 │   │   try:                                                                               │
# │ ❱  70 │   │   │   self._run_node(node, required)                                                 │
# │    71 │   │   │   self.status[node.name] = "finished"                                            │
# │    72 │   │   except Exception as e:                                                             │
# │    73 │   │   │   log.error("failed to run node", exc_info=e)                                    │
# │                                                                                                  │
# │ ╭─────────────────────────────────────────── locals ───────────────────────────────────────────╮ │
# │ │        e = AttributeError("'UserTrainingHistoryLookup' object has no attribute               │ │
# │ │            'interactions'")                                                                  │ │
# │ │      log = <BoundLoggerFilteringAtWarning(context={'node': 'history-lookup'},                │ │
# │ │            processors=[<function merge_contextvars at 0x75674ed33380>, <function             │ │
# │ │            add_log_level at 0x7567344e7b00>, <structlog.processors.StackInfoRenderer object  │ │
# │ │            at 0x7567340e9780>, <function set_exc_info at 0x7567340df7e0>,                    │ │
# │ │            <structlog.processors.TimeStamper object at 0x7567340f9000>,                      │ │
# │ │            <structlog.dev.ConsoleRenderer object at 0x7567340b1e80>])>                       │ │
# │ │     node = <lenskit.pipeline.nodes.ComponentInstanceNode object at 0x7565b551d5b0>           │ │
# │ │ required = False                                                                             │ │
# │ │     self = <lenskit.pipeline.runner.PipelineRunner object at 0x75660377f360>                 │ │
# │ │   status = 'pending'                                                                         │ │
# │ ╰──────────────────────────────────────────────────────────────────────────────────────────────╯ │
# │                                                                                                  │
# │ /home/toporek3112/miniconda3/envs/ml-3.13/lib/python3.13/site-packages/lenskit/pipeline/runner.p │
# │ y:92 in _run_node                                                                                │
# │                                                                                                  │
# │    89 │   │   │   case InputNode(name, types=types):                                             │
# │    90 │   │   │   │   self._inject_input(name, types, required)                                  │
# │    91 │   │   │   case ComponentInstanceNode(name, comp):                                        │
# │ ❱  92 │   │   │   │   self._run_component(name, comp, required)                                  │
# │    93 │   │   │   case _:  # pragma: nocover                                                     │
# │    94 │   │   │   │   raise PipelineError(f"invalid node {node}")                                │
# │    95                                                                                            │
# │                                                                                                  │
# │ ╭────────────────────────────────────── locals ──────────────────────────────────────╮           │
# │ │     comp = <UserTrainingHistoryLookup {                                            │           │
# │ │            │   "interaction_class": null                                           │           │
# │ │            }>                                                                      │           │
# │ │     name = 'history-lookup'                                                        │           │
# │ │     node = <lenskit.pipeline.nodes.ComponentInstanceNode object at 0x7565b551d5b0> │           │
# │ │ required = False                                                                   │           │
# │ │     self = <lenskit.pipeline.runner.PipelineRunner object at 0x75660377f360>       │           │
# │ ╰────────────────────────────────────────────────────────────────────────────────────╯           │
# │                                                                                                  │
# │ /home/toporek3112/miniconda3/envs/ml-3.13/lib/python3.13/site-packages/lenskit/pipeline/runner.p │
# │ y:169 in _run_component                                                                          │
# │                                                                                                  │
# │   166 │   │   │   in_data[iname] = ival                                                          │
# │   167 │   │                                                                                      │
# │   168 │   │   trace(log, "running component", component=comp)                                    │
# │ ❱ 169 │   │   self.state[name] = comp(**in_data)                                                 │
# │   170                                                                                            │
# │   171                                                                                            │
# │   172 @dataclass(eq=False)                                                                       │
# │                                                                                                  │
# │ ╭─────────────────────────────────────────── locals ───────────────────────────────────────────╮ │
# │ │     comp = <UserTrainingHistoryLookup {                                                      │ │
# │ │            │   "interaction_class": null                                                     │ │
# │ │            }>                                                                                │ │
# │ │     ilog = <BoundLoggerFilteringAtWarning(context={'pipeline': None, 'node':                 │ │
# │ │            'history-lookup', 'input_name': 'query', 'input_type':                            │ │
# │ │            lenskit.data.query.RecQuery | int | str | bytes | numpy.integer[typing.Any] |     │ │
# │ │            numpy.str_ | numpy.bytes_ | numpy.object_ | lenskit.data.items.ItemList | None},  │ │
# │ │            processors=[<function merge_contextvars at 0x75674ed33380>, <function             │ │
# │ │            add_log_level at 0x7567344e7b00>, <structlog.processors.StackInfoRenderer object  │ │
# │ │            at 0x7567340e9780>, <function set_exc_info at 0x7567340df7e0>,                    │ │
# │ │            <structlog.processors.TimeStamper object at 0x7567340f9000>,                      │ │
# │ │            <structlog.dev.ConsoleRenderer object at 0x7567340b1e80>])>                       │ │
# │ │  in_data = {'query': np.int64(9)}                                                            │ │
# │ │    iname = 'query'                                                                           │ │
# │ │   inputs = {                                                                                 │ │
# │ │            │   'query': lenskit.data.query.RecQuery | int | str | bytes |                    │ │
# │ │            numpy.integer[typing.Any] | numpy.str_ | numpy.bytes_ | numpy.object_ |           │ │
# │ │            lenskit.data.items.ItemList | None                                                │ │
# │ │            }                                                                                 │ │
# │ │     ireq = False                                                                             │ │
# │ │    itype = lenskit.data.query.RecQuery | int | str | bytes | numpy.integer[typing.Any] |     │ │
# │ │            numpy.str_ | numpy.bytes_ | numpy.object_ | lenskit.data.items.ItemList | None    │ │
# │ │     ival = np.int64(9)                                                                       │ │
# │ │     lazy = False                                                                             │ │
# │ │      log = <BoundLoggerFilteringAtWarning(context={'pipeline': None, 'node':                 │ │
# │ │            'history-lookup'}, processors=[<function merge_contextvars at 0x75674ed33380>,    │ │
# │ │            <function add_log_level at 0x7567344e7b00>,                                       │ │
# │ │            <structlog.processors.StackInfoRenderer object at 0x7567340e9780>, <function      │ │
# │ │            set_exc_info at 0x7567340df7e0>, <structlog.processors.TimeStamper object at      │ │
# │ │            0x7567340f9000>, <structlog.dev.ConsoleRenderer object at 0x7567340b1e80>])>      │ │
# │ │     name = 'history-lookup'                                                                  │ │
# │ │ required = False                                                                             │ │
# │ │     self = <lenskit.pipeline.runner.PipelineRunner object at 0x75660377f360>                 │ │
# │ │    snode = <lenskit.pipeline.nodes.InputNode object at 0x7565b560cfc0>                       │ │
# │ │      src = <lenskit.pipeline.nodes.InputNode object at 0x7565b560cfc0>                       │ │
# │ │   wiring = {'query': <lenskit.pipeline.nodes.InputNode object at 0x7565b560cfc0>}            │ │
# │ ╰──────────────────────────────────────────────────────────────────────────────────────────────╯ │
# │                                                                                                  │
# │ /home/toporek3112/miniconda3/envs/ml-3.13/lib/python3.13/site-packages/lenskit/basic/history.py: │
# │ 73 in __call__                                                                                   │
# │                                                                                                  │
# │    70 │   │   │   return query                                                                   │
# │    71 │   │                                                                                      │
# │    72 │   │   if query.user_items is None:                                                       │
# │ ❱  73 │   │   │   query.user_items = self.interactions.row_items(query.user_id)                  │
# │    74 │   │                                                                                      │
# │    75 │   │   return query                                                                       │
# │    76                                                                                            │
# │                                                                                                  │
# │ ╭─────────────────── locals ───────────────────╮                                                 │
# │ │ query = RecQuery(user_id=9, user_items=None) │                                                 │
# │ │  self = <UserTrainingHistoryLookup {         │                                                 │
# │ │         │   "interaction_class": null        │                                                 │
# │ │         }>                                   │                                                 │
# │ ╰──────────────────────────────────────────────╯                                                 │
# ╰──────────────────────────────────────────────────────────────────────────────────────────────────╯
# AttributeError: 'UserTrainingHistoryLookup' object has no attribute 'interactions'
# 2025-05-31 23:51:55 [error    ] failed to run node             node=history-lookup
# ╭─────────────────────────────── Traceback (most recent call last) ────────────────────────────────╮
# │ /home/toporek3112/miniconda3/envs/ml-3.13/lib/python3.13/site-packages/lenskit/pipeline/runner.p │
# │ y:70 in run                                                                                      │
# │                                                                                                  │
# │    67 │   │   trace(log, "processing node")                                                      │
# │    68 │   │   self.status[node.name] = "in-progress"                                             │
# │    69 │   │   try:                                                                               │
# │ ❱  70 │   │   │   self._run_node(node, required)                                                 │
# │    71 │   │   │   self.status[node.name] = "finished"                                            │
# │    72 │   │   except Exception as e:                                                             │
# │    73 │   │   │   log.error("failed to run node", exc_info=e)                                    │
# │                                                                                                  │
# │ ╭─────────────────────────────────────────── locals ───────────────────────────────────────────╮ │
# │ │        e = AttributeError("'UserTrainingHistoryLookup' object has no attribute               │ │
# │ │            'interactions'")                                                                  │ │
# │ │      log = <BoundLoggerFilteringAtWarning(context={'node': 'scorer'}, processors=[<function  │ │
# │ │            merge_contextvars at 0x75674ed33380>, <function add_log_level at 0x7567344e7b00>, │ │
# │ │            <structlog.processors.StackInfoRenderer object at 0x7567340e9780>, <function      │ │
# │ │            set_exc_info at 0x7567340df7e0>, <structlog.processors.TimeStamper object at      │ │
# │ │            0x7567340f9000>, <structlog.dev.ConsoleRenderer object at 0x7567340b1e80>])>      │ │
# │ │     node = <lenskit.pipeline.nodes.ComponentInstanceNode object at 0x756603794550>           │ │
# │ │ required = True                                                                              │ │
# │ │     self = <lenskit.pipeline.runner.PipelineRunner object at 0x75660377f360>                 │ │
# │ │   status = 'pending'                                                                         │ │
# │ ╰──────────────────────────────────────────────────────────────────────────────────────────────╯ │
# │                                                                                                  │
# │ /home/toporek3112/miniconda3/envs/ml-3.13/lib/python3.13/site-packages/lenskit/pipeline/runner.p │
# │ y:92 in _run_node                                                                                │
# │                                                                                                  │
# │    89 │   │   │   case InputNode(name, types=types):                                             │
# │    90 │   │   │   │   self._inject_input(name, types, required)                                  │
# │    91 │   │   │   case ComponentInstanceNode(name, comp):                                        │
# │ ❱  92 │   │   │   │   self._run_component(name, comp, required)                                  │
# │    93 │   │   │   case _:  # pragma: nocover                                                     │
# │    94 │   │   │   │   raise PipelineError(f"invalid node {node}")                                │
# │    95                                                                                            │
# │                                                                                                  │
# │ ╭────────────────────────────────────── locals ──────────────────────────────────────╮           │
# │ │     comp = <ItemKNNScorer {                                                        │           │
# │ │            │   "max_nbrs": 29,                                                     │           │
# │ │            │   "min_nbrs": 9,                                                      │           │
# │ │            │   "min_sim": 0.3,                                                     │           │
# │ │            │   "save_nbrs": null,                                                  │           │
# │ │            │   "feedback": "explicit",                                             │           │
# │ │            │   "block_size": 250                                                   │           │
# │ │            }>                                                                      │           │
# │ │     name = 'scorer'                                                                │           │
# │ │     node = <lenskit.pipeline.nodes.ComponentInstanceNode object at 0x756603794550> │           │
# │ │ required = True                                                                    │           │
# │ │     self = <lenskit.pipeline.runner.PipelineRunner object at 0x75660377f360>       │           │
# │ ╰────────────────────────────────────────────────────────────────────────────────────╯           │
# │                                                                                                  │
# │ /home/toporek3112/miniconda3/envs/ml-3.13/lib/python3.13/site-packages/lenskit/pipeline/runner.p │
# │ y:144 in _run_component                                                                          │
# │                                                                                                  │
# │   141 │   │   │   │   if lazy:                                                                   │
# │   142 │   │   │   │   │   ival = DeferredRun(self, iname, name, snode, required=ireq, data_typ   │
# │   143 │   │   │   │   else:                                                                      │
# │ ❱ 144 │   │   │   │   │   ival = self.run(snode, required=ireq)                                  │
# │   145 │   │   │                                                                                  │
# │   146 │   │   │   # bail out if we're failing to satisfy a dependency but it is not required     │
# │   147 │   │   │   if (                                                                           │
# │                                                                                                  │
# │ ╭─────────────────────────────────────────── locals ───────────────────────────────────────────╮ │
# │ │     comp = <ItemKNNScorer {                                                                  │ │
# │ │            │   "max_nbrs": 29,                                                               │ │
# │ │            │   "min_nbrs": 9,                                                                │ │
# │ │            │   "min_sim": 0.3,                                                               │ │
# │ │            │   "save_nbrs": null,                                                            │ │
# │ │            │   "feedback": "explicit",                                                       │ │
# │ │            │   "block_size": 250                                                             │ │
# │ │            }>                                                                                │ │
# │ │     ilog = <BoundLoggerFilteringAtWarning(context={'pipeline': None, 'node': 'scorer',       │ │
# │ │            'input_name': 'query', 'input_type': lenskit.data.query.RecQuery | int | str |    │ │
# │ │            bytes | numpy.integer[typing.Any] | numpy.str_ | numpy.bytes_ | numpy.object_ |   │ │
# │ │            lenskit.data.items.ItemList | None}, processors=[<function merge_contextvars at   │ │
# │ │            0x75674ed33380>, <function add_log_level at 0x7567344e7b00>,                      │ │
# │ │            <structlog.processors.StackInfoRenderer object at 0x7567340e9780>, <function      │ │
# │ │            set_exc_info at 0x7567340df7e0>, <structlog.processors.TimeStamper object at      │ │
# │ │            0x7567340f9000>, <structlog.dev.ConsoleRenderer object at 0x7567340b1e80>])>      │ │
# │ │  in_data = {}                                                                                │ │
# │ │    iname = 'query'                                                                           │ │
# │ │   inputs = {                                                                                 │ │
# │ │            │   'query': lenskit.data.query.RecQuery | int | str | bytes |                    │ │
# │ │            numpy.integer[typing.Any] | numpy.str_ | numpy.bytes_ | numpy.object_ |           │ │
# │ │            lenskit.data.items.ItemList | None,                                               │ │
# │ │            │   'items': <class 'lenskit.data.items.ItemList'>                                │ │
# │ │            }                                                                                 │ │
# │ │     ireq = False                                                                             │ │
# │ │    itype = lenskit.data.query.RecQuery | int | str | bytes | numpy.integer[typing.Any] |     │ │
# │ │            numpy.str_ | numpy.bytes_ | numpy.object_ | lenskit.data.items.ItemList | None    │ │
# │ │     lazy = False                                                                             │ │
# │ │      log = <BoundLoggerFilteringAtWarning(context={'pipeline': None, 'node': 'scorer'},      │ │
# │ │            processors=[<function merge_contextvars at 0x75674ed33380>, <function             │ │
# │ │            add_log_level at 0x7567344e7b00>, <structlog.processors.StackInfoRenderer object  │ │
# │ │            at 0x7567340e9780>, <function set_exc_info at 0x7567340df7e0>,                    │ │
# │ │            <structlog.processors.TimeStamper object at 0x7567340f9000>,                      │ │
# │ │            <structlog.dev.ConsoleRenderer object at 0x7567340b1e80>])>                       │ │
# │ │     name = 'scorer'                                                                          │ │
# │ │ required = True                                                                              │ │
# │ │     self = <lenskit.pipeline.runner.PipelineRunner object at 0x75660377f360>                 │ │
# │ │    snode = <lenskit.pipeline.nodes.ComponentInstanceNode object at 0x7565b551d5b0>           │ │
# │ │      src = <lenskit.pipeline.nodes.ComponentInstanceNode object at 0x7565b551d5b0>           │ │
# │ │   wiring = {                                                                                 │ │
# │ │            │   'items': <lenskit.pipeline.nodes.ComponentInstanceNode object at              │ │
# │ │            0x7565fd137df0>,                                                                  │ │
# │ │            │   'query': <lenskit.pipeline.nodes.ComponentInstanceNode object at              │ │
# │ │            0x7565b551d5b0>                                                                   │ │
# │ │            }                                                                                 │ │
# │ ╰──────────────────────────────────────────────────────────────────────────────────────────────╯ │
# │                                                                                                  │
# │ /home/toporek3112/miniconda3/envs/ml-3.13/lib/python3.13/site-packages/lenskit/pipeline/runner.p │
# │ y:75 in run                                                                                      │
# │                                                                                                  │
# │    72 │   │   except Exception as e:                                                             │
# │    73 │   │   │   log.error("failed to run node", exc_info=e)                                    │
# │    74 │   │   │   self.status[node.name] = "failed"                                              │
# │ ❱  75 │   │   │   raise e                                                                        │
# │    76 │   │                                                                                      │
# │    77 │   │   try:                                                                               │
# │    78 │   │   │   return self.state[node.name]                                                   │
# │                                                                                                  │
# │ ╭─────────────────────────────────────────── locals ───────────────────────────────────────────╮ │
# │ │      log = <BoundLoggerFilteringAtWarning(context={'node': 'history-lookup'},                │ │
# │ │            processors=[<function merge_contextvars at 0x75674ed33380>, <function             │ │
# │ │            add_log_level at 0x7567344e7b00>, <structlog.processors.StackInfoRenderer object  │ │
# │ │            at 0x7567340e9780>, <function set_exc_info at 0x7567340df7e0>,                    │ │
# │ │            <structlog.processors.TimeStamper object at 0x7567340f9000>,                      │ │
# │ │            <structlog.dev.ConsoleRenderer object at 0x7567340b1e80>])>                       │ │
# │ │     node = <lenskit.pipeline.nodes.ComponentInstanceNode object at 0x7565b551d5b0>           │ │
# │ │ required = False                                                                             │ │
# │ │     self = <lenskit.pipeline.runner.PipelineRunner object at 0x75660377f360>                 │ │
# │ │   status = 'pending'                                                                         │ │
# │ ╰──────────────────────────────────────────────────────────────────────────────────────────────╯ │
# │                                                                                                  │
# │ /home/toporek3112/miniconda3/envs/ml-3.13/lib/python3.13/site-packages/lenskit/pipeline/runner.p │
# │ y:70 in run                                                                                      │
# │                                                                                                  │
# │    67 │   │   trace(log, "processing node")                                                      │
# │    68 │   │   self.status[node.name] = "in-progress"                                             │
# │    69 │   │   try:                                                                               │
# │ ❱  70 │   │   │   self._run_node(node, required)                                                 │
# │    71 │   │   │   self.status[node.name] = "finished"                                            │
# │    72 │   │   except Exception as e:                                                             │
# │    73 │   │   │   log.error("failed to run node", exc_info=e)                                    │
# │                                                                                                  │
# │ ╭─────────────────────────────────────────── locals ───────────────────────────────────────────╮ │
# │ │      log = <BoundLoggerFilteringAtWarning(context={'node': 'history-lookup'},                │ │
# │ │            processors=[<function merge_contextvars at 0x75674ed33380>, <function             │ │
# │ │            add_log_level at 0x7567344e7b00>, <structlog.processors.StackInfoRenderer object  │ │
# │ │            at 0x7567340e9780>, <function set_exc_info at 0x7567340df7e0>,                    │ │
# │ │            <structlog.processors.TimeStamper object at 0x7567340f9000>,                      │ │
# │ │            <structlog.dev.ConsoleRenderer object at 0x7567340b1e80>])>                       │ │
# │ │     node = <lenskit.pipeline.nodes.ComponentInstanceNode object at 0x7565b551d5b0>           │ │
# │ │ required = False                                                                             │ │
# │ │     self = <lenskit.pipeline.runner.PipelineRunner object at 0x75660377f360>                 │ │
# │ │   status = 'pending'                                                                         │ │
# │ ╰──────────────────────────────────────────────────────────────────────────────────────────────╯ │
# │                                                                                                  │
# │ /home/toporek3112/miniconda3/envs/ml-3.13/lib/python3.13/site-packages/lenskit/pipeline/runner.p │
# │ y:92 in _run_node                                                                                │
# │                                                                                                  │
# │    89 │   │   │   case InputNode(name, types=types):                                             │
# │    90 │   │   │   │   self._inject_input(name, types, required)                                  │
# │    91 │   │   │   case ComponentInstanceNode(name, comp):                                        │
# │ ❱  92 │   │   │   │   self._run_component(name, comp, required)                                  │
# │    93 │   │   │   case _:  # pragma: nocover                                                     │
# │    94 │   │   │   │   raise PipelineError(f"invalid node {node}")                                │
# │    95                                                                                            │
# │                                                                                                  │
# │ ╭────────────────────────────────────── locals ──────────────────────────────────────╮           │
# │ │     comp = <UserTrainingHistoryLookup {                                            │           │
# │ │            │   "interaction_class": null                                           │           │
# │ │            }>                                                                      │           │
# │ │     name = 'history-lookup'                                                        │           │
# │ │     node = <lenskit.pipeline.nodes.ComponentInstanceNode object at 0x7565b551d5b0> │           │
# │ │ required = False                                                                   │           │
# │ │     self = <lenskit.pipeline.runner.PipelineRunner object at 0x75660377f360>       │           │
# │ ╰────────────────────────────────────────────────────────────────────────────────────╯           │
# │                                                                                                  │
# │ /home/toporek3112/miniconda3/envs/ml-3.13/lib/python3.13/site-packages/lenskit/pipeline/runner.p │
# │ y:169 in _run_component                                                                          │
# │                                                                                                  │
# │   166 │   │   │   in_data[iname] = ival                                                          │
# │   167 │   │                                                                                      │
# │   168 │   │   trace(log, "running component", component=comp)                                    │
# │ ❱ 169 │   │   self.state[name] = comp(**in_data)                                                 │
# │   170                                                                                            │
# │   171                                                                                            │
# │   172 @dataclass(eq=False)                                                                       │
# │                                                                                                  │
# │ ╭─────────────────────────────────────────── locals ───────────────────────────────────────────╮ │
# │ │     comp = <UserTrainingHistoryLookup {                                                      │ │
# │ │            │   "interaction_class": null                                                     │ │
# │ │            }>                                                                                │ │
# │ │     ilog = <BoundLoggerFilteringAtWarning(context={'pipeline': None, 'node':                 │ │
# │ │            'history-lookup', 'input_name': 'query', 'input_type':                            │ │
# │ │            lenskit.data.query.RecQuery | int | str | bytes | numpy.integer[typing.Any] |     │ │
# │ │            numpy.str_ | numpy.bytes_ | numpy.object_ | lenskit.data.items.ItemList | None},  │ │
# │ │            processors=[<function merge_contextvars at 0x75674ed33380>, <function             │ │
# │ │            add_log_level at 0x7567344e7b00>, <structlog.processors.StackInfoRenderer object  │ │
# │ │            at 0x7567340e9780>, <function set_exc_info at 0x7567340df7e0>,                    │ │
# │ │            <structlog.processors.TimeStamper object at 0x7567340f9000>,                      │ │
# │ │            <structlog.dev.ConsoleRenderer object at 0x7567340b1e80>])>                       │ │
# │ │  in_data = {'query': np.int64(9)}                                                            │ │
# │ │    iname = 'query'                                                                           │ │
# │ │   inputs = {                                                                                 │ │
# │ │            │   'query': lenskit.data.query.RecQuery | int | str | bytes |                    │ │
# │ │            numpy.integer[typing.Any] | numpy.str_ | numpy.bytes_ | numpy.object_ |           │ │
# │ │            lenskit.data.items.ItemList | None                                                │ │
# │ │            }                                                                                 │ │
# │ │     ireq = False                                                                             │ │
# │ │    itype = lenskit.data.query.RecQuery | int | str | bytes | numpy.integer[typing.Any] |     │ │
# │ │            numpy.str_ | numpy.bytes_ | numpy.object_ | lenskit.data.items.ItemList | None    │ │
# │ │     ival = np.int64(9)                                                                       │ │
# │ │     lazy = False                                                                             │ │
# │ │      log = <BoundLoggerFilteringAtWarning(context={'pipeline': None, 'node':                 │ │
# │ │            'history-lookup'}, processors=[<function merge_contextvars at 0x75674ed33380>,    │ │
# │ │            <function add_log_level at 0x7567344e7b00>,                                       │ │
# │ │            <structlog.processors.StackInfoRenderer object at 0x7567340e9780>, <function      │ │
# │ │            set_exc_info at 0x7567340df7e0>, <structlog.processors.TimeStamper object at      │ │
# │ │            0x7567340f9000>, <structlog.dev.ConsoleRenderer object at 0x7567340b1e80>])>      │ │
# │ │     name = 'history-lookup'                                                                  │ │
# │ │ required = False                                                                             │ │
# │ │     self = <lenskit.pipeline.runner.PipelineRunner object at 0x75660377f360>                 │ │
# │ │    snode = <lenskit.pipeline.nodes.InputNode object at 0x7565b560cfc0>                       │ │
# │ │      src = <lenskit.pipeline.nodes.InputNode object at 0x7565b560cfc0>                       │ │
# │ │   wiring = {'query': <lenskit.pipeline.nodes.InputNode object at 0x7565b560cfc0>}            │ │
# │ ╰──────────────────────────────────────────────────────────────────────────────────────────────╯ │
# │                                                                                                  │
# │ /home/toporek3112/miniconda3/envs/ml-3.13/lib/python3.13/site-packages/lenskit/basic/history.py: │
# │ 73 in __call__                                                                                   │
# │                                                                                                  │
# │    70 │   │   │   return query                                                                   │
# │    71 │   │                                                                                      │
# │    72 │   │   if query.user_items is None:                                                       │
# │ ❱  73 │   │   │   query.user_items = self.interactions.row_items(query.user_id)                  │
# │    74 │   │                                                                                      │
# │    75 │   │   return query                                                                       │
# │    76                                                                                            │
# │                                                                                                  │
# │ ╭─────────────────── locals ───────────────────╮                                                 │
# │ │ query = RecQuery(user_id=9, user_items=None) │                                                 │
# │ │  self = <UserTrainingHistoryLookup {         │                                                 │
# │ │         │   "interaction_class": null        │                                                 │
# │ │         }>                                   │                                                 │
# │ ╰──────────────────────────────────────────────╯                                                 │
# ╰──────────────────────────────────────────────────────────────────────────────────────────────────╯
# AttributeError: 'UserTrainingHistoryLookup' object has no attribute 'interactions'
# 2025-05-31 23:51:55 [error    ] failed to run node             node=scorer
# ╭─────────────────────────────── Traceback (most recent call last) ────────────────────────────────╮
# │ /home/toporek3112/miniconda3/envs/ml-3.13/lib/python3.13/site-packages/lenskit/pipeline/runner.p │
# │ y:70 in run                                                                                      │
# │                                                                                                  │
# │    67 │   │   trace(log, "processing node")                                                      │
# │    68 │   │   self.status[node.name] = "in-progress"                                             │
# │    69 │   │   try:                                                                               │
# │ ❱  70 │   │   │   self._run_node(node, required)                                                 │
# │    71 │   │   │   self.status[node.name] = "finished"                                            │
# │    72 │   │   except Exception as e:                                                             │
# │    73 │   │   │   log.error("failed to run node", exc_info=e)                                    │
# │                                                                                                  │
# │ ╭─────────────────────────────────────────── locals ───────────────────────────────────────────╮ │
# │ │        e = AttributeError("'UserTrainingHistoryLookup' object has no attribute               │ │
# │ │            'interactions'")                                                                  │ │
# │ │      log = <BoundLoggerFilteringAtWarning(context={'node': 'ranker'}, processors=[<function  │ │
# │ │            merge_contextvars at 0x75674ed33380>, <function add_log_level at 0x7567344e7b00>, │ │
# │ │            <structlog.processors.StackInfoRenderer object at 0x7567340e9780>, <function      │ │
# │ │            set_exc_info at 0x7567340df7e0>, <structlog.processors.TimeStamper object at      │ │
# │ │            0x7567340f9000>, <structlog.dev.ConsoleRenderer object at 0x7567340b1e80>])>      │ │
# │ │     node = <lenskit.pipeline.nodes.ComponentInstanceNode object at 0x7565fd1aa550>           │ │
# │ │ required = True                                                                              │ │
# │ │     self = <lenskit.pipeline.runner.PipelineRunner object at 0x75660377f360>                 │ │
# │ │   status = 'pending'                                                                         │ │
# │ ╰──────────────────────────────────────────────────────────────────────────────────────────────╯ │
# │                                                                                                  │
# │ /home/toporek3112/miniconda3/envs/ml-3.13/lib/python3.13/site-packages/lenskit/pipeline/runner.p │
# │ y:92 in _run_node                                                                                │
# │                                                                                                  │
# │    89 │   │   │   case InputNode(name, types=types):                                             │
# │    90 │   │   │   │   self._inject_input(name, types, required)                                  │
# │    91 │   │   │   case ComponentInstanceNode(name, comp):                                        │
# │ ❱  92 │   │   │   │   self._run_component(name, comp, required)                                  │
# │    93 │   │   │   case _:  # pragma: nocover                                                     │
# │    94 │   │   │   │   raise PipelineError(f"invalid node {node}")                                │
# │    95                                                                                            │
# │                                                                                                  │
# │ ╭────────────────────────────────────── locals ──────────────────────────────────────╮           │
# │ │     comp = <TopNRanker {                                                           │           │
# │ │            │   "n": -1                                                             │           │
# │ │            }>                                                                      │           │
# │ │     name = 'ranker'                                                                │           │
# │ │     node = <lenskit.pipeline.nodes.ComponentInstanceNode object at 0x7565fd1aa550> │           │
# │ │ required = True                                                                    │           │
# │ │     self = <lenskit.pipeline.runner.PipelineRunner object at 0x75660377f360>       │           │
# │ ╰────────────────────────────────────────────────────────────────────────────────────╯           │
# │                                                                                                  │
# │ /home/toporek3112/miniconda3/envs/ml-3.13/lib/python3.13/site-packages/lenskit/pipeline/runner.p │
# │ y:144 in _run_component                                                                          │
# │                                                                                                  │
# │   141 │   │   │   │   if lazy:                                                                   │
# │   142 │   │   │   │   │   ival = DeferredRun(self, iname, name, snode, required=ireq, data_typ   │
# │   143 │   │   │   │   else:                                                                      │
# │ ❱ 144 │   │   │   │   │   ival = self.run(snode, required=ireq)                                  │
# │   145 │   │   │                                                                                  │
# │   146 │   │   │   # bail out if we're failing to satisfy a dependency but it is not required     │
# │   147 │   │   │   if (                                                                           │
# │                                                                                                  │
# │ ╭─────────────────────────────────────────── locals ───────────────────────────────────────────╮ │
# │ │     comp = <TopNRanker {                                                                     │ │
# │ │            │   "n": -1                                                                       │ │
# │ │            }>                                                                                │ │
# │ │     ilog = <BoundLoggerFilteringAtWarning(context={'pipeline': None, 'node': 'ranker',       │ │
# │ │            'input_name': 'items', 'input_type': <class 'lenskit.data.items.ItemList'>},      │ │
# │ │            processors=[<function merge_contextvars at 0x75674ed33380>, <function             │ │
# │ │            add_log_level at 0x7567344e7b00>, <structlog.processors.StackInfoRenderer object  │ │
# │ │            at 0x7567340e9780>, <function set_exc_info at 0x7567340df7e0>,                    │ │
# │ │            <structlog.processors.TimeStamper object at 0x7567340f9000>,                      │ │
# │ │            <structlog.dev.ConsoleRenderer object at 0x7567340b1e80>])>                       │ │
# │ │  in_data = {}                                                                                │ │
# │ │    iname = 'items'                                                                           │ │
# │ │   inputs = {'items': <class 'lenskit.data.items.ItemList'>, 'n': int | None}                 │ │
# │ │     ireq = True                                                                              │ │
# │ │     lazy = False                                                                             │ │
# │ │      log = <BoundLoggerFilteringAtWarning(context={'pipeline': None, 'node': 'ranker'},      │ │
# │ │            processors=[<function merge_contextvars at 0x75674ed33380>, <function             │ │
# │ │            add_log_level at 0x7567344e7b00>, <structlog.processors.StackInfoRenderer object  │ │
# │ │            at 0x7567340e9780>, <function set_exc_info at 0x7567340df7e0>,                    │ │
# │ │            <structlog.processors.TimeStamper object at 0x7567340f9000>,                      │ │
# │ │            <structlog.dev.ConsoleRenderer object at 0x7567340b1e80>])>                       │ │
# │ │     name = 'ranker'                                                                          │ │
# │ │ required = True                                                                              │ │
# │ │     self = <lenskit.pipeline.runner.PipelineRunner object at 0x75660377f360>                 │ │
# │ │    snode = <lenskit.pipeline.nodes.ComponentInstanceNode object at 0x756603794550>           │ │
# │ │      src = <lenskit.pipeline.nodes.ComponentInstanceNode object at 0x756603794550>           │ │
# │ │   wiring = {                                                                                 │ │
# │ │            │   'items': <lenskit.pipeline.nodes.ComponentInstanceNode object at              │ │
# │ │            0x756603794550>,                                                                  │ │
# │ │            │   'n': <lenskit.pipeline.nodes.InputNode object at 0x7565b551d370>              │ │
# │ │            }                                                                                 │ │
# │ ╰──────────────────────────────────────────────────────────────────────────────────────────────╯ │
# │                                                                                                  │
# │ /home/toporek3112/miniconda3/envs/ml-3.13/lib/python3.13/site-packages/lenskit/pipeline/runner.p │
# │ y:75 in run                                                                                      │
# │                                                                                                  │
# │    72 │   │   except Exception as e:                                                             │
# │    73 │   │   │   log.error("failed to run node", exc_info=e)                                    │
# │    74 │   │   │   self.status[node.name] = "failed"                                              │
# │ ❱  75 │   │   │   raise e                                                                        │
# │    76 │   │                                                                                      │
# │    77 │   │   try:                                                                               │
# │    78 │   │   │   return self.state[node.name]                                                   │
# │                                                                                                  │
# │ ╭─────────────────────────────────────────── locals ───────────────────────────────────────────╮ │
# │ │      log = <BoundLoggerFilteringAtWarning(context={'node': 'scorer'}, processors=[<function  │ │
# │ │            merge_contextvars at 0x75674ed33380>, <function add_log_level at 0x7567344e7b00>, │ │
# │ │            <structlog.processors.StackInfoRenderer object at 0x7567340e9780>, <function      │ │
# │ │            set_exc_info at 0x7567340df7e0>, <structlog.processors.TimeStamper object at      │ │
# ...
# │    90 │   │   │   │   self._inject_input(name, types, required)                                  │
# │    91 │   │   │   case ComponentInstanceNode(name, comp):                                        │
# │ ❱  92 │   │   │   │   self._run_component(name, comp, required)                                  │
# │    93 │   │   │   case _:  # pragma: nocover                                                     │
# │    94 │   │   │   │   raise PipelineError(f"invalid node {node}")                                │
# │    95                                                                                            │
# │                                                                                                  │
# │ ╭────────────────────────────────────── locals ──────────────────────────────────────╮           │
# │ │     comp = <UserTrainingHistoryLookup {                                            │           │
# │ │            │   "interaction_class": null                                           │           │
# │ │            }>                                                                      │           │
# │ │     name = 'history-lookup'                                                        │           │
# │ │     node = <lenskit.pipeline.nodes.ComponentInstanceNode object at 0x7565b551d5b0> │           │
# │ │ required = False                                                                   │           │
# │ │     self = <lenskit.pipeline.runner.PipelineRunner object at 0x75660377f360>       │           │
# │ ╰────────────────────────────────────────────────────────────────────────────────────╯           │
# │                                                                                                  │
# │ /home/toporek3112/miniconda3/envs/ml-3.13/lib/python3.13/site-packages/lenskit/pipeline/runner.p │
# │ y:169 in _run_component                                                                          │
# │                                                                                                  │
# │   166 │   │   │   in_data[iname] = ival                                                          │
# │   167 │   │                                                                                      │
# │   168 │   │   trace(log, "running component", component=comp)                                    │
# │ ❱ 169 │   │   self.state[name] = comp(**in_data)                                                 │
# │   170                                                                                            │
# │   171                                                                                            │
# │   172 @dataclass(eq=False)                                                                       │
# │                                                                                                  │
# │ ╭─────────────────────────────────────────── locals ───────────────────────────────────────────╮ │
# │ │     comp = <UserTrainingHistoryLookup {                                                      │ │
# │ │            │   "interaction_class": null                                                     │ │
# │ │            }>                                                                                │ │
# │ │     ilog = <BoundLoggerFilteringAtWarning(context={'pipeline': None, 'node':                 │ │
# │ │            'history-lookup', 'input_name': 'query', 'input_type':                            │ │
# │ │            lenskit.data.query.RecQuery | int | str | bytes | numpy.integer[typing.Any] |     │ │
# │ │            numpy.str_ | numpy.bytes_ | numpy.object_ | lenskit.data.items.ItemList | None},  │ │
# │ │            processors=[<function merge_contextvars at 0x75674ed33380>, <function             │ │
# │ │            add_log_level at 0x7567344e7b00>, <structlog.processors.StackInfoRenderer object  │ │
# │ │            at 0x7567340e9780>, <function set_exc_info at 0x7567340df7e0>,                    │ │
# │ │            <structlog.processors.TimeStamper object at 0x7567340f9000>,                      │ │
# │ │            <structlog.dev.ConsoleRenderer object at 0x7567340b1e80>])>                       │ │
# │ │  in_data = {'query': np.int64(9)}                                                            │ │
# │ │    iname = 'query'                                                                           │ │
# │ │   inputs = {                                                                                 │ │
# │ │            │   'query': lenskit.data.query.RecQuery | int | str | bytes |                    │ │
# │ │            numpy.integer[typing.Any] | numpy.str_ | numpy.bytes_ | numpy.object_ |           │ │
# │ │            lenskit.data.items.ItemList | None                                                │ │
# │ │            }                                                                                 │ │
# │ │     ireq = False                                                                             │ │
# │ │    itype = lenskit.data.query.RecQuery | int | str | bytes | numpy.integer[typing.Any] |     │ │
# │ │            numpy.str_ | numpy.bytes_ | numpy.object_ | lenskit.data.items.ItemList | None    │ │
# │ │     ival = np.int64(9)                                                                       │ │
# │ │     lazy = False                                                                             │ │
# │ │      log = <BoundLoggerFilteringAtWarning(context={'pipeline': None, 'node':                 │ │
# │ │            'history-lookup'}, processors=[<function merge_contextvars at 0x75674ed33380>,    │ │
# │ │            <function add_log_level at 0x7567344e7b00>,                                       │ │
# │ │            <structlog.processors.StackInfoRenderer object at 0x7567340e9780>, <function      │ │
# │ │            set_exc_info at 0x7567340df7e0>, <structlog.processors.TimeStamper object at      │ │
# │ │            0x7567340f9000>, <structlog.dev.ConsoleRenderer object at 0x7567340b1e80>])>      │ │
# │ │     name = 'history-lookup'                                                                  │ │
# │ │ required = False                                                                             │ │
# │ │     self = <lenskit.pipeline.runner.PipelineRunner object at 0x75660377f360>                 │ │
# │ │    snode = <lenskit.pipeline.nodes.InputNode object at 0x7565b560cfc0>                       │ │
# │ │      src = <lenskit.pipeline.nodes.InputNode object at 0x7565b560cfc0>                       │ │
# │ │   wiring = {'query': <lenskit.pipeline.nodes.InputNode object at 0x7565b560cfc0>}            │ │
# │ ╰──────────────────────────────────────────────────────────────────────────────────────────────╯ │
# │                                                                                                  │
# │ /home/toporek3112/miniconda3/envs/ml-3.13/lib/python3.13/site-packages/lenskit/basic/history.py: │
# │ 73 in __call__                                                                                   │
# │                                                                                                  │
# │    70 │   │   │   return query                                                                   │
# │    71 │   │                                                                                      │
# │    72 │   │   if query.user_items is None:                                                       │
# │ ❱  73 │   │   │   query.user_items = self.interactions.row_items(query.user_id)                  │
# │    74 │   │                                                                                      │
# │    75 │   │   return query                                                                       │
# │    76                                                                                            │
# │                                                                                                  │
# │ ╭─────────────────── locals ───────────────────╮                                                 │
# │ │ query = RecQuery(user_id=9, user_items=None) │                                                 │
# │ │  self = <UserTrainingHistoryLookup {         │                                                 │
# │ │         │   "interaction_class": null        │                                                 │
# │ │         }>                                   │                                                 │
# │ ╰──────────────────────────────────────────────╯                                                 │
# ╰──────────────────────────────────────────────────────────────────────────────────────────────────╯
# AttributeError: 'UserTrainingHistoryLookup' object has no attribute 'interactions'
# 2025-05-31 23:51:56 [error    ] failed to run node             node=ranker
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[27], line 9
#       1 # recommend
#       2 # user_id =
#       3 # recs = recommend(pipe, user_id, n=15)
#    (...)      6 # print("Recommendations for user", user_id)
#       7 # movies_ratings[movies_ratings['movieId'].isin(recs.ids())]
# ----> 9 recs = recommend(base, lk_dataset.users.index[5], n=10) #
#      10 recs.to_df().head()
#
# File ~/miniconda3/envs/ml-3.13/lib/python3.13/site-packages/lenskit/operations.py:53, in recommend(pipeline, query, n, items, component)
#      51 if items is not None and not isinstance(items, ItemList):
#      52     items = ItemList(items)
# ---> 53 res = pipeline.run(node, query=query, n=n, items=items)
#      54 if not isinstance(res, ItemList):
#      55     raise TypeError("recommender pipeline did not return an item list")
#
# File ~/miniconda3/envs/ml-3.13/lib/python3.13/site-packages/lenskit/pipeline/_impl.py:368, in Pipeline.run(self, nodes, **kwargs)
#     365 else:
#     366     node_list = nodes
# --> 368 state = self.run_all(*node_list, **kwargs)
#     369 results = [state[self.node(n).name] for n in node_list]
#     371 if node_list is nodes:
#
# File ~/miniconda3/envs/ml-3.13/lib/python3.13/site-packages/lenskit/pipeline/_impl.py:412, in Pipeline.run_all(self, *nodes, **kwargs)
#     410 last = None
#     411 for node in node_list:
# --> 412     runner.run(node)
#     413     last = node.name
#     415 return PipelineState(
#     416     runner.state,
#     417     {a: t.name for (a, t) in self._aliases.items()},
#     418     default=last,
#     419     meta=self.meta(),
#     420 )
#
# File ~/miniconda3/envs/ml-3.13/lib/python3.13/site-packages/lenskit/pipeline/runner.py:75, in PipelineRunner.run(self, node, required)
#      73     log.error("failed to run node", exc_info=e)
#      74     self.status[node.name] = "failed"
# ---> 75     raise e
#      77 try:
#      78     return self.state[node.name]
#
# File ~/miniconda3/envs/ml-3.13/lib/python3.13/site-packages/lenskit/pipeline/runner.py:70, in PipelineRunner.run(self, node, required)
#      68 self.status[node.name] = "in-progress"
#      69 try:
# ---> 70     self._run_node(node, required)
#      71     self.status[node.name] = "finished"
#      72 except Exception as e:
#
# File ~/miniconda3/envs/ml-3.13/lib/python3.13/site-packages/lenskit/pipeline/runner.py:92, in PipelineRunner._run_node(self, node, required)
#      85 def _run_node(self, node: Node[Any], required: bool) -> None:
#      86     match node:
#      87         case LiteralNode(name, value):
#      88             self.state[name] = value
#      89         case InputNode(name, types=types):
#      90             self._inject_input(name, types, required)
#      91         case ComponentInstanceNode(name, comp):
# ---> 92             self._run_component(name, comp, required)
#      93         case _:  # pragma: nocover
#      94             raise PipelineError(f"invalid node {node}")
#
# File ~/miniconda3/envs/ml-3.13/lib/python3.13/site-packages/lenskit/pipeline/runner.py:144, in PipelineRunner._run_component(self, name, comp, required)
#     142         ival = DeferredRun(self, iname, name, snode, required=ireq, data_type=itype)
#     143     else:
# --> 144         ival = self.run(snode, required=ireq)
#     146 # bail out if we're failing to satisfy a dependency but it is not required
#     147 if (
#     148     ival is None
#     149     and itype
#    (...)    152     and not required
#     153 ):
#
# File ~/miniconda3/envs/ml-3.13/lib/python3.13/site-packages/lenskit/pipeline/runner.py:75, in PipelineRunner.run(self, node, required)
#      73     log.error("failed to run node", exc_info=e)
#      74     self.status[node.name] = "failed"
# ---> 75     raise e
#      77 try:
#      78     return self.state[node.name]
#
# File ~/miniconda3/envs/ml-3.13/lib/python3.13/site-packages/lenskit/pipeline/runner.py:70, in PipelineRunner.run(self, node, required)
#      68 self.status[node.name] = "in-progress"
#      69 try:
# ---> 70     self._run_node(node, required)
#      71     self.status[node.name] = "finished"
#      72 except Exception as e:
#
# File ~/miniconda3/envs/ml-3.13/lib/python3.13/site-packages/lenskit/pipeline/runner.py:92, in PipelineRunner._run_node(self, node, required)
#      85 def _run_node(self, node: Node[Any], required: bool) -> None:
#      86     match node:
#      87         case LiteralNode(name, value):
#      88             self.state[name] = value
#      89         case InputNode(name, types=types):
#      90             self._inject_input(name, types, required)
#      91         case ComponentInstanceNode(name, comp):
# ---> 92             self._run_component(name, comp, required)
#      93         case _:  # pragma: nocover
#      94             raise PipelineError(f"invalid node {node}")
#
# File ~/miniconda3/envs/ml-3.13/lib/python3.13/site-packages/lenskit/pipeline/runner.py:144, in PipelineRunner._run_component(self, name, comp, required)
#     142         ival = DeferredRun(self, iname, name, snode, required=ireq, data_type=itype)
#     143     else:
# --> 144         ival = self.run(snode, required=ireq)
#     146 # bail out if we're failing to satisfy a dependency but it is not required
#     147 if (
#     148     ival is None
#     149     and itype
#    (...)    152     and not required
#     153 ):
#
# File ~/miniconda3/envs/ml-3.13/lib/python3.13/site-packages/lenskit/pipeline/runner.py:75, in PipelineRunner.run(self, node, required)
#      73     log.error("failed to run node", exc_info=e)
#      74     self.status[node.name] = "failed"
# ---> 75     raise e
#      77 try:
#      78     return self.state[node.name]
#
# File ~/miniconda3/envs/ml-3.13/lib/python3.13/site-packages/lenskit/pipeline/runner.py:70, in PipelineRunner.run(self, node, required)
#      68 self.status[node.name] = "in-progress"
#      69 try:
# ---> 70     self._run_node(node, required)
#      71     self.status[node.name] = "finished"
#      72 except Exception as e:
#
# File ~/miniconda3/envs/ml-3.13/lib/python3.13/site-packages/lenskit/pipeline/runner.py:92, in PipelineRunner._run_node(self, node, required)
#      85 def _run_node(self, node: Node[Any], required: bool) -> None:
#      86     match node:
#      87         case LiteralNode(name, value):
#      88             self.state[name] = value
#      89         case InputNode(name, types=types):
#      90             self._inject_input(name, types, required)
#      91         case ComponentInstanceNode(name, comp):
# ---> 92             self._run_component(name, comp, required)
#      93         case _:  # pragma: nocover
#      94             raise PipelineError(f"invalid node {node}")
#
# File ~/miniconda3/envs/ml-3.13/lib/python3.13/site-packages/lenskit/pipeline/runner.py:169, in PipelineRunner._run_component(self, name, comp, required)
#     166     in_data[iname] = ival
#     168 trace(log, "running component", component=comp)
# --> 169 self.state[name] = comp(**in_data)
#
# File ~/miniconda3/envs/ml-3.13/lib/python3.13/site-packages/lenskit/basic/history.py:73, in UserTrainingHistoryLookup.__call__(self, query)
#      70     return query
#      72 if query.user_items is None:
# ---> 73     query.user_items = self.interactions.row_items(query.user_id)
#      75 return query
#
# AttributeError: 'UserTrainingHistoryLookup' object has no attribute 'interactions'

# %%
# Out:
# Empty DataFrame
# Columns: [item_id, item_num, score, rank]
# Index: []
